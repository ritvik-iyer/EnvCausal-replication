# %% [markdown]
# ### Import Libraries

# %%
# !pip install econml
# Out:
# Collecting econml
#   Using cached https://files.pythonhosted.org/packages/38/09/ee219469caa671f314f863c240486902f391a0c7333b4beb953b3b432160/econml-0.12.0-cp37-cp37m-macosx_10_9_x86_64.whl
# Requirement already satisfied: scipy>1.4.0 in /opt/anaconda3/lib/python3.7/site-packages (from econml) (1.7.1)
# Collecting sparse (from econml)
#   Using cached https://files.pythonhosted.org/packages/26/21/c796aaef2e9c805ea2e608893a67ff88395ded66788122959ac710ad4d6e/sparse-0.13.0-py2.py3-none-any.whl
# Requirement already satisfied: numba!=0.42.1 in /opt/anaconda3/lib/python3.7/site-packages (from econml) (0.45.1)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.7/site-packages (from econml) (0.25.1)
# Collecting shap<0.40.0,>=0.38.1 (from econml)
#   Using cached https://files.pythonhosted.org/packages/b9/f4/c5b95cddae15be80f8e58b25edceca105aa83c0b8c86a1edad24a6af80d3/shap-0.39.0.tar.gz
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.7/site-packages (from econml) (1.17.2)
# Requirement already satisfied: scikit-learn>0.22.0 in /opt/anaconda3/lib/python3.7/site-packages (from econml) (1.0.1)
# Collecting lightgbm (from econml)
#   Using cached https://files.pythonhosted.org/packages/9a/59/d38a95be739922078b00b9a9727077310c4913bc593dc35aa7b873b5b756/lightgbm-3.3.1-py3-none-macosx_10_14_x86_64.macosx_10_15_x86_64.macosx_11_0_x86_64.whl
# Requirement already satisfied: statsmodels>=0.10 in /opt/anaconda3/lib/python3.7/site-packages (from econml) (0.10.1)
# Requirement already satisfied: dowhy in /opt/anaconda3/lib/python3.7/site-packages (from econml) (0.6)
# Requirement already satisfied: joblib>=0.13.0 in /opt/anaconda3/lib/python3.7/site-packages (from econml) (0.13.2)
# Requirement already satisfied: llvmlite>=0.29.0dev0 in /opt/anaconda3/lib/python3.7/site-packages (from numba!=0.42.1->econml) (0.29.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/anaconda3/lib/python3.7/site-packages (from pandas->econml) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.7/site-packages (from pandas->econml) (2019.3)
# Requirement already satisfied: tqdm>4.25.0 in /opt/anaconda3/lib/python3.7/site-packages (from shap<0.40.0,>=0.38.1->econml) (4.36.1)
# Requirement already satisfied: slicer==0.0.7 in /opt/anaconda3/lib/python3.7/site-packages (from shap<0.40.0,>=0.38.1->econml) (0.0.7)
# Requirement already satisfied: cloudpickle in /opt/anaconda3/lib/python3.7/site-packages (from shap<0.40.0,>=0.38.1->econml) (1.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from scikit-learn>0.22.0->econml) (3.0.0)
# Requirement already satisfied: wheel in /opt/anaconda3/lib/python3.7/site-packages (from lightgbm->econml) (0.33.6)
# Requirement already satisfied: patsy>=0.4.0 in /opt/anaconda3/lib/python3.7/site-packages (from statsmodels>=0.10->econml) (0.5.1)
# Requirement already satisfied: networkx>=2.0 in /opt/anaconda3/lib/python3.7/site-packages (from dowhy->econml) (2.3)
# Requirement already satisfied: pydot>=1.4 in /opt/anaconda3/lib/python3.7/site-packages (from dowhy->econml) (1.4.2)
# Requirement already satisfied: sympy>=1.4 in /opt/anaconda3/lib/python3.7/site-packages (from dowhy->econml) (1.4)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas->econml) (1.12.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/anaconda3/lib/python3.7/site-packages (from networkx>=2.0->dowhy->econml) (4.4.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /opt/anaconda3/lib/python3.7/site-packages (from pydot>=1.4->dowhy->econml) (2.4.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.7/site-packages (from sympy>=1.4->dowhy->econml) (1.1.0)
# Building wheels for collected packages: shap
#   Building wheel for shap (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/c8/5qwfh0m1607f_l6763w47wzh0000gn/T/pip-install-7zogawxg/shap/setup.py'"'"'; __file__='"'"'/private/var/folders/c8/5qwfh0m1607f_l6763w47wzh0000gn/T/pip-install-7zogawxg/shap/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/c8/5qwfh0m1607f_l6763w47wzh0000gn/T/pip-wheel-mcrtz_oe --python-tag cp37
#        cwd: /private/var/folders/c8/5qwfh0m1607f_l6763w47wzh0000gn/T/pip-install-7zogawxg/shap/
#   Complete output (119 lines):
#   The nvcc binary could not be located in your $PATH. Either  add it to your path, or set $CUDAHOME to enable CUDA
#   Error building cuda module: TypeError('cannot unpack non-iterable NoneType object')
#   WARNING: Could not compile cuda extensions
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-3.7
#   creating build/lib.macosx-10.9-x86_64-3.7/shap
#   copying shap/datasets.py -> build/lib.macosx-10.9-x86_64-3.7/shap
#   copying shap/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap
#   copying shap/links.py -> build/lib.macosx-10.9-x86_64-3.7/shap
#   copying shap/_explanation.py -> build/lib.macosx-10.9-x86_64-3.7/shap
#   copying shap/_serializable.py -> build/lib.macosx-10.9-x86_64-3.7/shap
#   creating build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/_explainer.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/_partition.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/_gradient.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/mimic.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/_sampling.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/_linear.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/_permutation.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/_gpu_tree.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/_kernel.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/_additive.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/tf_utils.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/_exact.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/_tree.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   copying shap/explainers/pytree.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#   creating build/lib.macosx-10.9-x86_64-3.7/shap/explainers/other
#   copying shap/explainers/other/_coefficent.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/other
#   copying shap/explainers/other/_maple.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/other
#   copying shap/explainers/other/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/other
#   copying shap/explainers/other/_random.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/other
#   copying shap/explainers/other/_treegain.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/other
#   copying shap/explainers/other/_lime.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/other
#   creating build/lib.macosx-10.9-x86_64-3.7/shap/explainers/_deep
#   copying shap/explainers/_deep/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/_deep
#   copying shap/explainers/_deep/deep_pytorch.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/_deep
#   copying shap/explainers/_deep/deep_tf.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/_deep
#   creating build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_heatmap.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_partial_dependence.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_monitoring.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_violin.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_decision.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_text.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_force_matplotlib.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_force.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_group_difference.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_embedding.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_beeswarm.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_bar.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_image.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_scatter.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_waterfall.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_labels.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   copying shap/plots/_utils.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#   creating build/lib.macosx-10.9-x86_64-3.7/shap/plots/colors
#   copying shap/plots/colors/_colors.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots/colors
#   copying shap/plots/colors/_colorconv.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots/colors
#   copying shap/plots/colors/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots/colors
#   creating build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#   copying shap/benchmark/metrics.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#   copying shap/benchmark/models.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#   copying shap/benchmark/methods.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#   copying shap/benchmark/framework.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#   copying shap/benchmark/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#   copying shap/benchmark/measures.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#   copying shap/benchmark/plots.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#   copying shap/benchmark/experiments.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#   copying shap/benchmark/perturbation.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#   creating build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#   copying shap/maskers/_fixed_composite.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#   copying shap/maskers/_fixed.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#   copying shap/maskers/_masker.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#   copying shap/maskers/_text.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#   copying shap/maskers/_tabular.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#   copying shap/maskers/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#   copying shap/maskers/_image.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#   copying shap/maskers/_output_composite.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#   copying shap/maskers/_composite.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#   creating build/lib.macosx-10.9-x86_64-3.7/shap/utils
#   copying shap/utils/transformers.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#   copying shap/utils/_clustering.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#   copying shap/utils/_keras.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#   copying shap/utils/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#   copying shap/utils/_show_progress.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#   copying shap/utils/_masked_model.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#   copying shap/utils/_legacy.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#   copying shap/utils/_general.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#   copying shap/utils/image.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#   creating build/lib.macosx-10.9-x86_64-3.7/shap/actions
#   copying shap/actions/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/actions
#   copying shap/actions/_action.py -> build/lib.macosx-10.9-x86_64-3.7/shap/actions
#   copying shap/actions/_optimizer.py -> build/lib.macosx-10.9-x86_64-3.7/shap/actions
#   creating build/lib.macosx-10.9-x86_64-3.7/shap/models
#   copying shap/models/_topk_lm.py -> build/lib.macosx-10.9-x86_64-3.7/shap/models
#   copying shap/models/_transformers_pipeline.py -> build/lib.macosx-10.9-x86_64-3.7/shap/models
#   copying shap/models/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/models
#   copying shap/models/_text_generation.py -> build/lib.macosx-10.9-x86_64-3.7/shap/models
#   copying shap/models/_model.py -> build/lib.macosx-10.9-x86_64-3.7/shap/models
#   copying shap/models/_teacher_forcing.py -> build/lib.macosx-10.9-x86_64-3.7/shap/models
#   creating build/lib.macosx-10.9-x86_64-3.7/shap/plots/resources
#   copying shap/plots/resources/bundle.js -> build/lib.macosx-10.9-x86_64-3.7/shap/plots/resources
#   copying shap/plots/resources/logoSmallGray.png -> build/lib.macosx-10.9-x86_64-3.7/shap/plots/resources
#   creating build/lib.macosx-10.9-x86_64-3.7/shap/cext
#   copying shap/cext/tree_shap.h -> build/lib.macosx-10.9-x86_64-3.7/shap/cext
#   running build_ext
#   numpy.get_include() /opt/anaconda3/lib/python3.7/site-packages/numpy/core/include
#   building 'shap._cext' extension
#   creating build/temp.macosx-10.9-x86_64-3.7
#   creating build/temp.macosx-10.9-x86_64-3.7/shap
#   creating build/temp.macosx-10.9-x86_64-3.7/shap/cext
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/opt/anaconda3/include -arch x86_64 -I/opt/anaconda3/include -arch x86_64 -I/opt/anaconda3/include/python3.7m -I/opt/anaconda3/lib/python3.7/site-packages/numpy/core/include -c shap/cext/_cext.cc -o build/temp.macosx-10.9-x86_64-3.7/shap/cext/_cext.o
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for shap
#   Running setup.py clean for shap
# Failed to build shap
# ERROR: sparse 0.13.0 has requirement numba>=0.49, but you'll have numba 0.45.1 which is incompatible.
# Installing collected packages: sparse, shap, lightgbm, econml
#   Running setup.py install for shap ... error
#     ERROR: Command errored out with exit status 1:
#      command: /opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/c8/5qwfh0m1607f_l6763w47wzh0000gn/T/pip-install-7zogawxg/shap/setup.py'"'"'; __file__='"'"'/private/var/folders/c8/5qwfh0m1607f_l6763w47wzh0000gn/T/pip-install-7zogawxg/shap/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/c8/5qwfh0m1607f_l6763w47wzh0000gn/T/pip-record-cvbog70d/install-record.txt --single-version-externally-managed --compile
#          cwd: /private/var/folders/c8/5qwfh0m1607f_l6763w47wzh0000gn/T/pip-install-7zogawxg/shap/
#     Complete output (119 lines):
#     The nvcc binary could not be located in your $PATH. Either  add it to your path, or set $CUDAHOME to enable CUDA
#     Error building cuda module: TypeError('cannot unpack non-iterable NoneType object')
#     WARNING: Could not compile cuda extensions
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-x86_64-3.7
#     creating build/lib.macosx-10.9-x86_64-3.7/shap
#     copying shap/datasets.py -> build/lib.macosx-10.9-x86_64-3.7/shap
#     copying shap/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap
#     copying shap/links.py -> build/lib.macosx-10.9-x86_64-3.7/shap
#     copying shap/_explanation.py -> build/lib.macosx-10.9-x86_64-3.7/shap
#     copying shap/_serializable.py -> build/lib.macosx-10.9-x86_64-3.7/shap
#     creating build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/_explainer.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/_partition.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/_gradient.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/mimic.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/_sampling.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/_linear.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/_permutation.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/_gpu_tree.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/_kernel.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/_additive.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/tf_utils.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/_exact.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/_tree.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     copying shap/explainers/pytree.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers
#     creating build/lib.macosx-10.9-x86_64-3.7/shap/explainers/other
#     copying shap/explainers/other/_coefficent.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/other
#     copying shap/explainers/other/_maple.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/other
#     copying shap/explainers/other/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/other
#     copying shap/explainers/other/_random.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/other
#     copying shap/explainers/other/_treegain.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/other
#     copying shap/explainers/other/_lime.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/other
#     creating build/lib.macosx-10.9-x86_64-3.7/shap/explainers/_deep
#     copying shap/explainers/_deep/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/_deep
#     copying shap/explainers/_deep/deep_pytorch.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/_deep
#     copying shap/explainers/_deep/deep_tf.py -> build/lib.macosx-10.9-x86_64-3.7/shap/explainers/_deep
#     creating build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_heatmap.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_partial_dependence.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_monitoring.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_violin.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_decision.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_text.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_force_matplotlib.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_force.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_group_difference.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_embedding.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_beeswarm.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_bar.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_image.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_scatter.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_waterfall.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_labels.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     copying shap/plots/_utils.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots
#     creating build/lib.macosx-10.9-x86_64-3.7/shap/plots/colors
#     copying shap/plots/colors/_colors.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots/colors
#     copying shap/plots/colors/_colorconv.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots/colors
#     copying shap/plots/colors/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/plots/colors
#     creating build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#     copying shap/benchmark/metrics.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#     copying shap/benchmark/models.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#     copying shap/benchmark/methods.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#     copying shap/benchmark/framework.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#     copying shap/benchmark/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#     copying shap/benchmark/measures.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#     copying shap/benchmark/plots.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#     copying shap/benchmark/experiments.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#     copying shap/benchmark/perturbation.py -> build/lib.macosx-10.9-x86_64-3.7/shap/benchmark
#     creating build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#     copying shap/maskers/_fixed_composite.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#     copying shap/maskers/_fixed.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#     copying shap/maskers/_masker.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#     copying shap/maskers/_text.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#     copying shap/maskers/_tabular.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#     copying shap/maskers/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#     copying shap/maskers/_image.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#     copying shap/maskers/_output_composite.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#     copying shap/maskers/_composite.py -> build/lib.macosx-10.9-x86_64-3.7/shap/maskers
#     creating build/lib.macosx-10.9-x86_64-3.7/shap/utils
#     copying shap/utils/transformers.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#     copying shap/utils/_clustering.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#     copying shap/utils/_keras.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#     copying shap/utils/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#     copying shap/utils/_show_progress.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#     copying shap/utils/_masked_model.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#     copying shap/utils/_legacy.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#     copying shap/utils/_general.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#     copying shap/utils/image.py -> build/lib.macosx-10.9-x86_64-3.7/shap/utils
#     creating build/lib.macosx-10.9-x86_64-3.7/shap/actions
#     copying shap/actions/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/actions
#     copying shap/actions/_action.py -> build/lib.macosx-10.9-x86_64-3.7/shap/actions
#     copying shap/actions/_optimizer.py -> build/lib.macosx-10.9-x86_64-3.7/shap/actions
#     creating build/lib.macosx-10.9-x86_64-3.7/shap/models
#     copying shap/models/_topk_lm.py -> build/lib.macosx-10.9-x86_64-3.7/shap/models
#     copying shap/models/_transformers_pipeline.py -> build/lib.macosx-10.9-x86_64-3.7/shap/models
#     copying shap/models/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/shap/models
#     copying shap/models/_text_generation.py -> build/lib.macosx-10.9-x86_64-3.7/shap/models
#     copying shap/models/_model.py -> build/lib.macosx-10.9-x86_64-3.7/shap/models
#     copying shap/models/_teacher_forcing.py -> build/lib.macosx-10.9-x86_64-3.7/shap/models
#     creating build/lib.macosx-10.9-x86_64-3.7/shap/plots/resources
#     copying shap/plots/resources/bundle.js -> build/lib.macosx-10.9-x86_64-3.7/shap/plots/resources
#     copying shap/plots/resources/logoSmallGray.png -> build/lib.macosx-10.9-x86_64-3.7/shap/plots/resources
#     creating build/lib.macosx-10.9-x86_64-3.7/shap/cext
#     copying shap/cext/tree_shap.h -> build/lib.macosx-10.9-x86_64-3.7/shap/cext
#     running build_ext
#     numpy.get_include() /opt/anaconda3/lib/python3.7/site-packages/numpy/core/include
#     building 'shap._cext' extension
#     creating build/temp.macosx-10.9-x86_64-3.7
#     creating build/temp.macosx-10.9-x86_64-3.7/shap
#     creating build/temp.macosx-10.9-x86_64-3.7/shap/cext
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/opt/anaconda3/include -arch x86_64 -I/opt/anaconda3/include -arch x86_64 -I/opt/anaconda3/include/python3.7m -I/opt/anaconda3/lib/python3.7/site-packages/numpy/core/include -c shap/cext/_cext.cc -o build/temp.macosx-10.9-x86_64-3.7/shap/cext/_cext.o
#     xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#     error: command 'gcc' failed with exit status 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/c8/5qwfh0m1607f_l6763w47wzh0000gn/T/pip-install-7zogawxg/shap/setup.py'"'"'; __file__='"'"'/private/var/folders/c8/5qwfh0m1607f_l6763w47wzh0000gn/T/pip-install-7zogawxg/shap/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/c8/5qwfh0m1607f_l6763w47wzh0000gn/T/pip-record-cvbog70d/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.

# %%
# %load_ext autoreload

# %autoreload 2
# Libraries for data processing and math 
import pandas as pd
import numpy as np

# Library for causal estimation 
import dowhy
from dowhy import CausalModel
import econml
from sklearn.preprocessing import MinMaxScaler
from causal_estimate import ate_estimate_refutation 

# Library for file path manipulation 
import os

# Set seed to control randomness
np.random.seed(156)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1118452a19b8> in <module>
#       9 import dowhy
#      10 from dowhy import CausalModel
# ---> 11 import econml
#      12 from sklearn.preprocessing import MinMaxScaler
#      13 from causal_estimate import ate_estimate_refutation
#
# ModuleNotFoundError: No module named 'econml'

# %%
# Declare Causal Graph for all time series data
causal_graph = """
digraph {
days; 
ACTV; 
TEMP; 
U[label="Unobserved Confounders"];
HUM; 
WSPD; 
PRES; 
NO2; 
O3; 
PM2.5; 
PM10; 
SO2; 
CO; 
Case; 
days->ACTV; days->TEMP; days->Case; 
U->ACTV; U->TEMP; U->PRES; U->O3; U->HUM; U->WSPD; 
ACTV->NO2; ACTV->Case; ACTV->PM2.5; ACTV->PM10; ACTV->SO2; ACTV->CO; 
PRES->NO2; PRES->O3; PRES->PM2.5; PRES->PM10; PRES->SO2; PRES->C0; 
TEMP->PRES; TEMP->HUM; 
HUM->PRES; HUM->N02; HUM->O3; HUM->PM2.5; HUM->PM10; HUM->SO2; HUM->CO;
WSPD->N02; WSPD->O3; WSPD->PM2.5; WSPD->PM10; WSPD->SO2; WSPD->CO; 
NO2->O3; 
}
"""

# %% [markdown]
# ### Read Data

# %%
# Load the data and train the XGBoost models
root = os.path.dirname(os.getcwd())
data_dir = os.path.join(root, 'data')
### Cluster 1 Overall ###
c1_overall_path = os.path.join(data_dir, 'time_cluster_1.csv')
c1_overall = pd.read_csv(c1_overall_path)
all_vars = ['days', 'ACTV', 'TEMP', 'HUM', 'WSPD', 'PRES', 'NO2', 'O3', 'PM2.5', 'PM10', 'SO2', 'CO', 'Case']
cluster1_df = c1_overall[all_vars]
# Normalize the data 
scaler = MinMaxScaler()
normalized = scaler.fit_transform(cluster1_df.values)
cluster1_df_norm = pd.DataFrame(normalized)
cluster1_df_norm.columns = cluster1_df.columns
cluster1_df_norm.head()
# Out:
#        days      ACTV      TEMP       HUM      WSPD      PRES       NO2  \
# 0  0.000000  0.570104  0.502793  0.993318  0.000000  0.869388  0.910256
# 1  0.012987  0.509862  0.477654  1.000000  0.000000  0.869388  0.717949
# 2  0.025974  0.441704  0.469274  0.997773  0.062016  0.889796  0.589744
# 3  0.038961  0.312268  0.446927  0.979955  0.062016  0.922449  0.371795
# 4  0.051948  0.213670  0.430168  0.975501  0.124031  0.938776  0.262821
#
#          O3     PM2.5      PM10       SO2        CO      Case
# 0  0.425481  0.382456  0.240291  0.310345  0.491803  0.000000
# 1  0.414663  0.266667  0.156553  0.258621  0.368852  0.063063
# 2  0.485577  0.245614  0.203883  0.275862  0.327869  0.099099
# 3  0.485577  0.133333  0.131068  0.241379  0.213115  0.216216
# 4  0.512019  0.101754  0.128641  0.275862  0.196721  0.216216

# %% [markdown]
# ### Causal Refutation for Cluster 1: RCC

# %%
# ATE refutation
treatments = ['PRES', 'TEMP', 'HUM', 'WSPD']
curr_treatments = []
ate_linear2 = []
ate_forest2 = []
for treatment in treatments:
    try:
        est_forest, ref_forest = ate_estimate_refutation(treatment='PRES', data=cluster1_df_norm, outcome='Case',
                                causal_graph=causal_graph, model_type='nonlinear', refutation_type='RCC')
        curr_treatments.append(treatment)
        ate_linear2.append(first)
        ate_forest2.append(second)
    except Exception as e:
        continue 
for idx in range(len(curr_treatments)):
    print(f'Treatment: {curr_treatments[idx]}')
    print('-----------------------------')
    print(f'ATE Linear: {ate_linear2[idx]}')
    print(f'ATE Forest: {ate_forest2[idx]}')

# %%
est, ref = ate_estimate_refutation(treatment='PRES', data=cluster1_df_norm, outcome='Case',
                                causal_graph=causal_graph, model_type='linear', refutation_type='RCC')

# %%
print(est)
# Out:
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: nonparametric-ate
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#    d
# ───────(Expectation(Case|HUM,CO,ACTV,WSPD,TEMP,days))
# d[PRES]
# Estimand assumption 1, Unconfoundedness: If U→{PRES} and U→Case then P(Case|PRES,HUM,CO,ACTV,WSPD,TEMP,days,U) = P(Case|PRES,HUM,CO,ACTV,WSPD,TEMP,days)
#
# ## Realized estimand
# b: Case~PRES+HUM+CO+ACTV+WSPD+TEMP+days+PRES*ACTV
# Target units: ate
#
# ## Estimate
# Mean value: 0.07008893758689774
# ### Conditional Estimates
# __categorical__ACTV
# (-0.001, 0.166]    0.086774
# (0.166, 0.319]     0.079717
# (0.319, 0.477]     0.070445
# (0.477, 0.634]     0.062457
# (0.634, 1.0]       0.050898
# dtype: float64

# %%
print(ref)
# Out:
# Refute: Add a Random Common Cause
# Estimated effect:0.07008893758689774
# New effect:0.06756068743849529
